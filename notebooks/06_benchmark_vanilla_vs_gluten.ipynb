# %% [markdown]
# # 06 — Vanilla vs Gluten/Velox Benchmark
#
# Run this notebook **twice**:
# 1. `make up` → run → saves `results_vanilla.json`
# 2. `make down && make up-gluten` → run → saves `results_gluten.json`
#
# Cell 'Compare results' renders the chart once both files exist.

# %%
import os, time
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import *

GLUTEN_ENABLED = os.environ.get('GLUTEN_ENABLED', 'false').lower() == 'true'
MASTER   = 'spark://spark-master:7077'
DATA_DIR = '/workspace/data'

spark = (
    SparkSession.builder
    .appName('spark-notebook')
    .master(MASTER)
    .config('spark.executor.memory', '2g')
    .config('spark.driver.memory',   '1g')
    .config('spark.executor.cores',  '2')
    # Disable BypassMergeSortShuffleWriter — incompatible with Gluten columnar serializer
    .config('spark.shuffle.sort.bypassMergeThreshold', '0')
    .getOrCreate()
)
spark.sparkContext.setLogLevel('WARN')
mode = 'Gluten/Velox' if GLUTEN_ENABLED else 'Vanilla'
print(f'Spark {spark.version}  |  Mode: {mode}')
spark.range(3).show()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/08 07:03:41 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# W20260408 07:03:43.667688   134 MemoryArbitrator.cpp:84] Query memory capacity[288.00MB] is set for NOOP arbitrator which has no capacity enforcement
# 26/04/08 07:03:44 WARN SparkShimProvider: Spark runtime version 4.0.2 is not matched with Gluten's fully tested version 4.0.1
# Spark 4.0.2  |  Mode: Gluten/Velox
# 26/04/08 07:03:47 WARN GlutenFallbackReporter: Validation failed for plan: Project[QueryId=0], due to:
#  - Validation failed with exception from: ProjectExecTransformer, reason: Not supported to map spark function name to substrait function name: toprettystring(id#0L, Some(Etc/UTC)), class name: ToPrettyString.
# [Stage 0:>                                                          (0 + 4) / 4]
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# +---+

# %% [markdown]
# ## Load benchmark data

# %%
from pathlib import Path
import json, datetime

RESULTS_DIR = '/workspace/notebooks/results'
Path(RESULTS_DIR).mkdir(exist_ok=True)
MODE = 'gluten' if GLUTEN_ENABLED else 'vanilla'

lineitem = spark.read.parquet(f'{DATA_DIR}/lineitem.parquet')
orders   = spark.read.parquet(f'{DATA_DIR}/orders.parquet')
customer = spark.read.parquet(f'{DATA_DIR}/customer.parquet')

lineitem.createOrReplaceTempView('lineitem')
orders.createOrReplaceTempView('orders')
customer.createOrReplaceTempView('customer')
print(f'Mode: {MODE} | lineitem: {lineitem.count():,} | orders: {orders.count():,}')
# Out:
# 26/04/08 07:03:50 WARN GlutenFallbackReporter: Validation failed for plan: Exchange[QueryId=4], due to: [FallbackByBackendSettings] Validation failed on node Exchange
# Mode: gluten | lineitem: 600,000 | orders: 150,000
# 26/04/08 07:03:51 WARN GlutenFallbackReporter: Validation failed for plan: Exchange[QueryId=5], due to: [FallbackByBackendSettings] Validation failed on node Exchange

# %% [markdown]
# ## Benchmark queries (TPC-H subset)

# %%
QUERIES = {
    "Q1_agg": """
        SELECT l_returnflag, l_linestatus,
               SUM(l_quantity) AS sum_qty,
               SUM(l_extendedprice) AS sum_base_price,
               SUM(l_extendedprice * (1-l_discount)) AS sum_disc_price,
               SUM(l_extendedprice * (1-l_discount) * (1+l_tax)) AS sum_charge,
               AVG(l_quantity) AS avg_qty,
               COUNT(*) AS count_order
        FROM lineitem
        WHERE l_shipdate <= date '1998-09-01'
        GROUP BY l_returnflag, l_linestatus
        ORDER BY l_returnflag, l_linestatus
    """,
    "Q3_join": """
        SELECT l_orderkey, SUM(l_extendedprice*(1-l_discount)) AS revenue,
               o_orderdate, o_orderpriority
        FROM customer JOIN orders ON c_custkey = o_custkey
                      JOIN lineitem ON l_orderkey = o_orderkey
        WHERE o_orderdate < date '1995-03-15'
          AND l_shipdate  > date '1995-03-15'
        GROUP BY l_orderkey, o_orderdate, o_orderpriority
        ORDER BY revenue DESC LIMIT 10
    """,
    "Q6_filter": """
        SELECT SUM(l_extendedprice * l_discount) AS revenue
        FROM lineitem
        WHERE l_shipdate >= date '1994-01-01'
          AND l_shipdate  < date '1995-01-01'
          AND l_discount BETWEEN 0.05 AND 0.07
          AND l_quantity < 24
    """,
    "Q_window": """
        SELECT l_orderkey,
               SUM(l_extendedprice) OVER (PARTITION BY l_returnflag ORDER BY l_shipdate) AS running_total
        FROM lineitem LIMIT 1000
    """,
}
WARMUP = "Q6_filter"
print("Queries ready:", list(QUERIES.keys()))


# Q_window uses shuffle with columnar serializer incompatible in Gluten 1.6.0 + Spark 4.0
# Remove it from Gluten runs to avoid UnsupportedOperationException
if GLUTEN_ENABLED:
    QUERIES.pop('Q_window', None)
    print('NOTE: Q_window skipped in Gluten mode (shuffle serializer incompatibility in Gluten 1.6.0)')
# Out:
# Queries ready: ['Q1_agg', 'Q3_join', 'Q6_filter', 'Q_window']
# NOTE: Q_window skipped in Gluten mode (shuffle serializer incompatibility in Gluten 1.6.0)

# %% [markdown]
# ## Warmup + Run

# %%
def run_query(name, sql, runs=3):
    times = []
    for _ in range(runs):
        t0 = time.time()
        spark.sql(sql).collect()
        times.append(round(time.time()-t0, 3))
    return {"query": name, "mode": MODE, "times": times,
            "median": round(sorted(times)[len(times)//2], 3),
            "ts": datetime.datetime.now().isoformat()}


print('Warming up...')
spark.sql(QUERIES[WARMUP]).collect()

results = []
for name, sql in QUERIES.items():
    print(f'Running {name}...', end=' ')
    try:
        r = run_query(name, sql)
        print(f'median={r["median"]}s')
        results.append(r)
    except Exception as e:
        print(f'SKIPPED ({type(e).__name__}: {str(e)[:80]})')

out = f'{RESULTS_DIR}/results_{MODE}.json'
Path(out).write_text(json.dumps(results, indent=2))
print(f'Saved → {out}')
# Out:
# Warming up...
# 26/04/08 07:04:00 WARN GlutenFallbackReporter: Validation failed for plan: Exchange[QueryId=6], due to: [FallbackByBackendSettings] Validation failed on node Exchange
# Running Q1_agg...
# 26/04/08 07:04:01 WARN GlutenFallbackReporter: Validation failed for plan: Exchange[QueryId=7], due to: [FallbackByBackendSettings] Validation failed on node Exchange
# 26/04/08 07:04:01 WARN GlutenFallbackReporter: Validation failed for plan: Exchange[QueryId=7], due to: [FallbackByBackendSettings] Validation failed on node Exchange
# 26/04/08 07:04:02 WARN GlutenFallbackReporter: Validation failed for plan: Exchange[QueryId=8], due to: [FallbackByBackendSettings] Validation failed on node Exchange
# 26/04/08 07:04:02 WARN GlutenFallbackReporter: Validation failed for plan: Exchange[QueryId=8], due to: [FallbackByBackendSettings] Validation failed on node Exchange
# 26/04/08 07:04:02 WARN GlutenFallbackReporter: Validation failed for plan: Exchange[QueryId=9], due to: [FallbackByBackendSettings] Validation failed on node Exchange
# 26/04/08 07:04:03 WARN GlutenFallbackReporter: Validation failed for plan: Exchange[QueryId=9], due to: [FallbackByBackendSettings] Validation failed on node Exchange
# median=0.508s
# Running Q3_join...
# 26/04/08 07:04:03 WARN GlutenFallbackReporter: Validation failed for plan: Exchange[QueryId=10], due to: [FallbackByBackendSettings] Validation failed on node Exchange
# 26/04/08 07:04:04 WARN GlutenFallbackReporter: Validation failed for plan: TakeOrderedAndProject[QueryId=10], due to: [FallbackByBackendSettings] Validation failed on node TakeOrderedAndProject
# 26/04/08 07:04:04 WARN GlutenFallbackReporter: Validation failed for plan: Exchange[QueryId=11], due to: [FallbackByBackendSettings] Validation failed on node Exchange
# 26/04/08 07:04:04 WARN GlutenFallbackReporter: Validation failed for plan: TakeOrderedAndProject[QueryId=11], due to: [FallbackByBackendSettings] Validation failed on node TakeOrderedAndProject
# 26/04/08 07:04:05 WARN GlutenFallbackReporter: Validation failed for plan: Exchange[QueryId=12], due to: [FallbackByBackendSettings] Validation failed on node Exchange
# 26/04/08 07:04:05 WARN GlutenFallbackReporter: Validation failed for plan: TakeOrderedAndProject[QueryId=12], due to: [FallbackByBackendSettings] Validation failed on node TakeOrderedAndProject
# median=0.661s
# Running Q6_filter...
# 26/04/08 07:04:05 WARN GlutenFallbackReporter: Validation failed for plan: Exchange[QueryId=13], due to: [FallbackByBackendSettings] Validation failed on node Exchange
# 26/04/08 07:04:06 WARN GlutenFallbackReporter: Validation failed for plan: Exchange[QueryId=14], due to: [FallbackByBackendSettings] Validation failed on node Exchange
# 26/04/08 07:04:06 WARN GlutenFallbackReporter: Validation failed for plan: Exchange[QueryId=15], due to: [FallbackByBackendSettings] Validation failed on node Exchange
# median=0.179s
# Saved → /workspace/notebooks/results/results_gluten.json

# %% [markdown]
# ## Verify Gluten offloading

# %%
if GLUTEN_ENABLED:
    plan = spark.sql(QUERIES["Q1_agg"]).explain(True)
    print("Look for 'Velox' prefixed operators in the plan above.")
else:
    print("Vanilla mode — no Gluten operators.")
# Out:
# == Parsed Logical Plan ==
# 'Sort ['l_returnflag ASC NULLS FIRST, 'l_linestatus ASC NULLS FIRST], true
# +- 'Aggregate ['l_returnflag, 'l_linestatus], ['l_returnflag, 'l_linestatus, 'SUM('l_quantity) AS sum_qty#286, 'SUM('l_extendedprice) AS sum_base_price#287, 'SUM(('l_extendedprice * (1 - 'l_discount))) AS sum_disc_price#288, 'SUM((('l_extendedprice * (1 - 'l_discount)) * (1 + 'l_tax))) AS sum_charge#289, 'AVG('l_quantity) AS avg_qty#290, 'COUNT(1) AS count_order#291]
#    +- 'Filter ('l_shipdate <= 1998-09-01)
#       +- 'UnresolvedRelation [lineitem], [], false
#
# == Analyzed Logical Plan ==
# l_returnflag: string, l_linestatus: string, sum_qty: double, sum_base_price: double, sum_disc_price: double, sum_charge: double, avg_qty: double, count_order: bigint
# Sort [l_returnflag#11 ASC NULLS FIRST, l_linestatus#12 ASC NULLS FIRST], true
# +- Aggregate [l_returnflag#11, l_linestatus#12], [l_returnflag#11, l_linestatus#12, sum(l_quantity#7) AS sum_qty#286, sum(l_extendedprice#8) AS sum_base_price#287, sum((l_extendedprice#8 * (cast(1 as double) - l_discount#9))) AS sum_disc_price#288, sum(((l_extendedprice#8 * (cast(1 as double) - l_discount#9)) * (cast(1 as double) + l_tax#10))) AS sum_charge#289, avg(l_quantity#7) AS avg_qty#290, count(1) AS count_order#291L]
#    +- Filter (l_shipdate#13 <= 1998-09-01)
#       +- SubqueryAlias lineitem
#          +- View (`lineitem`, [l_orderkey#5L, l_partkey#6L, l_quantity#7, l_extendedprice#8, l_discount#9, l_tax#10, l_returnflag#11, l_linestatus#12, l_shipdate#13, l_commitdate#14])
#             +- Relation [l_orderkey#5L,l_partkey#6L,l_quantity#7,l_extendedprice#8,l_discount#9,l_tax#10,l_returnflag#11,l_linestatus#12,l_shipdate#13,l_commitdate#14] parquet
#
# == Optimized Logical Plan ==
# Sort [l_returnflag#11 ASC NULLS FIRST, l_linestatus#12 ASC NULLS FIRST], true
# +- Aggregate [l_returnflag#11, l_linestatus#12], [l_returnflag#11, l_linestatus#12, sum(l_quantity#7) AS sum_qty#286, sum(l_extendedprice#8) AS sum_base_price#287, sum((l_extendedprice#8 * (1.0 - l_discount#9))) AS sum_disc_price#288, sum(((l_extendedprice#8 * (1.0 - l_discount#9)) * (1.0 + l_tax#10))) AS sum_charge#289, avg(l_quantity#7) AS avg_qty#290, count(1) AS count_order#291L]
#    +- Project [l_quantity#7, l_extendedprice#8, l_discount#9, l_tax#10, l_returnflag#11, l_linestatus#12]
#       +- Filter (isnotnull(l_shipdate#13) AND (l_shipdate#13 <= 1998-09-01))
#          +- Relation [l_orderkey#5L,l_partkey#6L,l_quantity#7,l_extendedprice#8,l_discount#9,l_tax#10,l_returnflag#11,l_linestatus#12,l_shipdate#13,l_commitdate#14] parquet
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Sort [l_returnflag#11 ASC NULLS FIRST, l_linestatus#12 ASC NULLS FIRST], true, 0
#    +- Exchange rangepartitioning(l_returnflag#11 ASC NULLS FIRST, l_linestatus#12 ASC NULLS FIRST, 24), ENSURE_REQUIREMENTS, [plan_id=5019]
#       +- HashAggregate(keys=[l_returnflag#11, l_linestatus#12], functions=[sum(l_quantity#7), sum(l_extendedprice#8), sum((l_extendedprice#8 * (1.0 - l_discount#9))), sum(((l_extendedprice#8 * (1.0 - l_discount#9)) * (1.0 + l_tax#10))), avg(l_quantity#7), count(1)], output=[l_returnflag#11, l_linestatus#12, sum_qty#286, sum_base_price#287, sum_disc_price#288, sum_charge#289, avg_qty#290, count_order#291L])
#          +- Exchange hashpartitioning(l_returnflag#11, l_linestatus#12, 24), ENSURE_REQUIREMENTS, [plan_id=5016]
#             +- HashAggregate(keys=[l_returnflag#11, l_linestatus#12], functions=[partial_sum(l_quantity#7), partial_sum(l_extendedprice#8), partial_sum((l_extendedprice#8 * (1.0 - l_discount#9))), partial_sum(((l_extendedprice#8 * (1.0 - l_discount#9)) * (1.0 + l_tax#10))), partial_avg(l_quantity#7), partial_count(1)], output=[l_returnflag#11, l_linestatus#12, sum#305, sum#306, sum#307, sum#308, sum#309, count#310L, count#311L])
#                +- Project [l_quantity#7, l_extendedprice#8, l_discount#9, l_tax#10, l_returnflag#11, l_linestatus#12]
#                   +- Filter (isnotnull(l_shipdate#13) AND (l_shipdate#13 <= 1998-09-01))
#                      +- FileScan parquet [l_quantity#7,l_extendedprice#8,l_discount#9,l_tax#10,l_returnflag#11,l_linestatus#12,l_shipdate#13] Batched: true, DataFilters: [isnotnull(l_shipdate#13), (l_shipdate#13 <= 1998-09-01)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/workspace/data/lineitem.parquet], PartitionFilters: [], PushedFilters: [IsNotNull(l_shipdate), LessThanOrEqual(l_shipdate,1998-09-01)], ReadSchema: struct<l_quantity:double,l_extendedprice:double,l_discount:double,l_tax:double,l_returnflag:strin...
#
# Look for 'Velox' prefixed operators in the plan above.

# %% [markdown]
# ## Compare results

# %%
import matplotlib.pyplot as plt
import numpy as np

v_file = Path(f"{RESULTS_DIR}/results_vanilla.json")
g_file = Path(f"{RESULTS_DIR}/results_gluten.json")

if not v_file.exists() or not g_file.exists():
    print("Run both vanilla and gluten passes first.")
else:
    v = {r["query"]: r["median"] for r in json.loads(v_file.read_text())}
    g = {r["query"]: r["median"] for r in json.loads(g_file.read_text())}

    # Only compare queries present in BOTH results
    # (Q_window is skipped in Gluten mode due to shuffle serializer incompatibility)
    queries = [q for q in v.keys() if q in g]
    skipped = [q for q in v.keys() if q not in g]
    if skipped:
        print(f"NOTE: {skipped} skipped in Gluten mode — excluded from comparison")

    speedups = [round(v[q]/g[q], 2) for q in queries]

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    x = np.arange(len(queries))
    w = 0.35
    axes[0].bar(x-w/2, [v[q] for q in queries], w, label='Vanilla', color='steelblue')
    axes[0].bar(x+w/2, [g[q] for q in queries], w, label='Gluten', color='darkorange')
    axes[0].set_xticks(x); axes[0].set_xticklabels(queries, rotation=20)
    axes[0].set_ylabel('seconds (median)'); axes[0].set_title('Query Time: Vanilla vs Gluten')
    axes[0].legend()

    colors = ['green' if s>=1 else 'red' for s in speedups]
    axes[1].bar(queries, speedups, color=colors)
    axes[1].axhline(1.0, color='black', linestyle='--')
    axes[1].set_ylabel('speedup (vanilla/gluten)'); axes[1].set_title('Gluten Speedup (>1 = faster)')
    for i,(q,s) in enumerate(zip(queries, speedups)):
        axes[1].text(i, s+0.02, f'{s}x', ha='center', fontsize=9)

    plt.tight_layout()
    plt.savefig(f"{RESULTS_DIR}/benchmark.png", dpi=150)
    plt.show()
    print("Speedups:", dict(zip(queries, speedups)))
# Out:
# NOTE: ['Q_window'] skipped in Gluten mode — excluded from comparison
# Speedups: {'Q1_agg': 0.99, 'Q3_join': 1.07, 'Q6_filter': 1.06}
